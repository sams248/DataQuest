# %% [markdown]
# ## Error Handling

# %% [markdown]
# We'll be working with legislators.csv, which records information on every historical member of the U.S. Congress. The file includes these columns:
#
# - `last_name` - the legislator's last name
# - `first_name` - the legislator's first name
# - `birthday` - the legislator's birthday
# - `gender` - the legislator's gender
# - `type` - the chamber in which the legislator served - either Senate (sen) or House of Representatives (rep)
# - `state` - the state the legislator represents
# - `party` - the legislator's party affiliation

# %%
import csv
f = open("legislators.csv")
csvread = csv.reader(f)
legislators = list(csvread)

legislators[0:5]
# Out:
# [['last_name', 'first_name', 'birthday', 'gender', 'type', 'state', 'party'],
#  ['Abercrombie', 'Neil', '6/26/1938', 'M', 'Rep', 'HI', 'D'],
#  ['Ackerman', 'Gary', '11/19/1942', 'M', 'Rep', 'NY', 'D'],
#  ['Aderholt', 'Robert', '7/22/1965', 'M', 'Rep', 'AL', 'R'],
#  ['Akaka', 'Daniel', '9/11/1924', 'M', 'Sen', 'HI', 'D']]

# %%
gender = []
for row in legislators[1:]:
    gender.append(row[3])
    
gender[0:5]
# Out:
# ['M', 'M', 'M', 'M', 'M']

# %%
print(set(gender))
# Out:
# {'', 'F', 'M'}

# %%
party = []
for row in legislators[1:]:
    party.append(row[6])
print(set(party))
# Out:
# {'I', 'D', 'R'}

# %%
print(legislators[0:20])
# Out:
# [['last_name', 'first_name', 'birthday', 'gender', 'type', 'state', 'party'], ['Abercrombie', 'Neil', '6/26/1938', 'M', 'Rep', 'HI', 'D'], ['Ackerman', 'Gary', '11/19/1942', 'M', 'Rep', 'NY', 'D'], ['Aderholt', 'Robert', '7/22/1965', 'M', 'Rep', 'AL', 'R'], ['Akaka', 'Daniel', '9/11/1924', 'M', 'Sen', 'HI', 'D'], ['Allard', 'Wayne', '12/2/1943', 'M', 'Sen', 'CO', 'R'], ['Andrews', 'Robert', '8/4/1957', 'M', 'Rep', 'NJ', 'D'], ['Allen', 'Thomas', '4/16/1945', '', 'Rep', 'ME', 'D'], ['Akin', 'W.', '7/5/1947', 'M', 'Rep', 'MO', 'R'], ['Alexander', 'Lamar', '7/3/1940', 'M', 'Sen', 'TN', 'R'], ['Alexander', 'Rodney', '12/5/1946', 'M', 'Rep', 'LA', 'R'], ['Altmire', 'Jason', '3/7/1968', 'M', 'Rep', 'PA', 'D'], ['Arcuri', 'Michael', '6/11/1959', 'M', 'Rep', 'NY', 'D'], ['Adler', 'John', '8/23/1959', 'M', 'Rep', 'NJ', 'D'], ['Austria', 'Steve', '10/12/1958', 'M', 'Rep', 'OH', 'R'], ['Adams', 'Sandy', '12/14/1956', 'F', 'Rep', 'FL', 'R'], ['Amash', 'Justin', '4/18/1980', 'M', 'Rep', 'MI', 'R'], ['Ayotte', 'Kelly', '6/27/1968', 'F', 'Sen', 'NH', 'R'], ['Amodei', 'Mark', '6/12/1958', 'M', 'Rep', 'NV', 'R'], ['Bachus', 'Spencer', '12/28/1947', 'M', 'Rep', 'AL', 'R']]

# %%
for row in legislators:
    if row[3] == '':
        row[3] = 'M'

# %%
birth_years = []
for row in legislators[1:]:
    parts = row[2].split("/")
    birth_years.append(parts[2])
birth_years[0:5]
# Out:
# ['1938', '1942', '1965', '1924', '1943']

# %%
# an example for handling error
try:
    float("hello")
except Exception:
    print("Error converting to float")
# Out:
# Error converting to float

# %%
# another example for handling error
try:
    int(" ")
except Exception as exc:
    print(type(exc))
    print(str(exc))
# Out:
# <class 'ValueError'>
# invalid literal for int() with base 10: ' '

# %%
converted_years = [] 
for y in birth_years:
    try:
        converted_years.append(int(y))
    except Exception:
        pass

print(converted_years[0:10])
# Out:
# [1938, 1942, 1965, 1924, 1943, 1957, 1945, 1947, 1940, 1946]

# %%
for row in legislators[1:]:
    parts = row[2].split('/')
    try:
        birth_year = int(parts[2])
    except Exception:
        birth_year = 0
    row.append(birth_year)

# %%
legislators[0].append("birth_year")
print(legislators[0:5])
# Out:
# [['last_name', 'first_name', 'birthday', 'gender', 'type', 'state', 'party', 'birth_year'], ['Abercrombie', 'Neil', '6/26/1938', 'M', 'Rep', 'HI', 'D', 1938, 1938], ['Ackerman', 'Gary', '11/19/1942', 'M', 'Rep', 'NY', 'D', 1942, 1942], ['Aderholt', 'Robert', '7/22/1965', 'M', 'Rep', 'AL', 'R', 1965, 1965], ['Akaka', 'Daniel', '9/11/1924', 'M', 'Sen', 'HI', 'D', 1924, 1924]]

# %%
last_value = 1
for row in legislators[1:]:
    if row[7] == 0:
        row[7] = last_value
        last_value = row[7]

# %%
print(legislators)
# Out:
# [['last_name', 'first_name', 'birthday', 'gender', 'type', 'state', 'party', 'birth_year'], ['Abercrombie', 'Neil', '6/26/1938', 'M', 'Rep', 'HI', 'D', 1938, 1938], ['Ackerman', 'Gary', '11/19/1942', 'M', 'Rep', 'NY', 'D', 1942, 1942], ['Aderholt', 'Robert', '7/22/1965', 'M', 'Rep', 'AL', 'R', 1965, 1965], ['Akaka', 'Daniel', '9/11/1924', 'M', 'Sen', 'HI', 'D', 1924, 1924], ['Allard', 'Wayne', '12/2/1943', 'M', 'Sen', 'CO', 'R', 1943, 1943], ['Andrews', 'Robert', '8/4/1957', 'M', 'Rep', 'NJ', 'D', 1957, 1957], ['Allen', 'Thomas', '4/16/1945', 'M', 'Rep', 'ME', 'D', 1945, 1945], ['Akin', 'W.', '7/5/1947', 'M', 'Rep', 'MO', 'R', 1947, 1947], ['Alexander', 'Lamar', '7/3/1940', 'M', 'Sen', 'TN', 'R', 1940, 1940], ['Alexander', 'Rodney', '12/5/1946', 'M', 'Rep', 'LA', 'R', 1946, 1946], ['Altmire', 'Jason', '3/7/1968', 'M', 'Rep', 'PA', 'D', 1968, 1968], ['Arcuri', 'Michael', '6/11/1959', 'M', 'Rep', 'NY', 'D', 1959, 1959], ['Adler', 'John', '8/23/1959', 'M', 'Rep', 'NJ', 'D', 1959, 1959], ['Austria', 'Steve', '10/12/1958', 'M', 'Rep', 'OH', 'R', 1958, 1958], ['Adams', 'Sandy', '12/14/1956', 'F', 'Rep', 'FL', 'R', 1956, 1956], ['Amash', 'Justin', '4/18/1980', 'M', 'Rep', 'MI', 'R', 1980, 1980], ['Ayotte', 'Kelly', '6/27/1968', 'F', 'Sen', 'NH', 'R', 1968, 1968], ['Amodei', 'Mark', '6/12/1958', 'M', 'Rep', 'NV', 'R', 1958, 1958], ['Bachus', 'Spencer', '12/28/1947', 'M', 'Rep', 'AL', 'R', 1947, 1947], ['Baker', 'Richard', '5/22/1948', 'M', 'Rep', 'LA', 'R', 1948, 1948], ['Bartlett', 'Roscoe', '6/3/1926', 'M', 'Rep', 'MD', 'R', 1926, 1926], ['Barton', 'Joe', '9/15/1949', 'M', 'Rep', 'TX', 'R', 1949, 1949], ['Bass', 'Charles', '1/8/1952', 'M', 'Rep', 'NH', 'R', 1952, 1952], ['Baucus', 'Max', '12/11/1941', 'M', 'Sen', 'MT', 'D', 1941, 1941], ['Becerra', 'Xavier', '1/26/1958', 'M', 'Rep', 'CA', 'D', 1958, 1958], ['Bennett', 'Robert', '9/18/1933', 'M', 'Sen', 'UT', 'R', 1933, 1933], ['Berman', 'Howard', '4/15/1941', 'M', 'Rep', 'CA', 'D', 1941, 1941], ['Berry', 'Robert', '8/27/1942', 'M', 'Rep', 'AR', 'D', 1942, 1942], ['Biden', 'Joseph', '11/20/1942', 'M', 'Sen', 'DE', 'D', 1942, 1942], ['Bilbray', 'Brian', '1/28/1951', 'M', 'Rep', 'CA', 'R', 1951, 1951], ['Bingaman', 'Jeff', '10/3/1943', 'M', 'Sen', 'NM', 'D', 1943, 1943], ['Bishop', 'Sanford', '2/4/1947', 'M', 'Rep', 'GA', 'D', 1947, 1947], ['Blumenauer', 'Earl', '8/16/1948', 'M', 'Rep', 'OR', 'D', 1948, 1948], ['Blunt', 'Roy', '1/10/1950', 'M', 'Sen', 'MO', 'R', 1950, 1950], ['Boehner', 'John', '11/17/1949', 'M', 'Rep', 'OH', 'R', 1949, 1949], ['Bond', 'Christopher', '3/6/1939', 'M', 'Sen', 'MO', 'R', 1939, 1939], ['Boswell', 'Leonard', '1/10/1934', 'M', 'Rep', 'IA', 'D', 1934, 1934], ['Boucher', 'Frederick', '8/1/1946', 'M', 'Rep', 'VA', 'D', 1946, 1946], ['Boxer', 'Barbara', '11/11/1940', 'F', 'Sen', 'CA', 'D', 1940, 1940], ['Boyd', 'Allen', '6/6/1945', 'M', 'Rep', 'FL', 'D', 1945, 1945], ['Brady', 'Kevin', '4/11/1955', 'M', 'Rep', 'TX', 'R', 1955, 1955], ['Brown', 'Corrine', '11/11/1946', 'F', 'Rep', 'FL', 'D', 1946, 1946], ['Brown', 'Sherrod', '11/9/1952', 'M', 'Sen', 'OH', 'D', 1952, 1952], ['Brownback', 'Samuel', '9/12/1956', 'M', 'Sen', 'KS', 'R', 1956, 1956], ['Bunning', 'Jim', '10/23/1931', 'M', 'Sen', 'KY', 'R', 1931, 1931], ['Burr', 'Richard', '11/30/1955', 'M', 'Sen', 'NC', 'R', 1955, 1955], ['Burton', 'Dan', '6/21/1938', 'M', 'Rep', 'IN', 'R', 1938, 1938], ['Buyer', 'Stephen', '11/26/1958', 'M', 'Rep', 'IN', 'R', 1958, 1958], ['Byrd', 'Robert', '11/20/1917', 'M', 'Sen', 'WV', 'D', 1917, 1917], ['Brady', 'Robert', '4/7/1945', 'M', 'Rep', 'PA', 'D', 1945, 1945], ['Bono Mack', 'Mary', '10/24/1961', 'F', 'Rep', 'CA', 'R', 1961, 1961], ['Baird', 'Brian', '3/7/1956', 'M', 'Rep', 'WA', 'D', 1956, 1956], ['Baldwin', 'Tammy', '2/11/1962', 'F', 'Sen', 'WI', 'D', 1962, 1962], ['Berkley', 'Shelley', '1/20/1951', 'F', 'Rep', 'NV', 'D', 1951, 1951], ['Biggert', 'Judy', '8/15/1937', 'F', 'Rep', 'IL', 'R', 1937, 1937], ['Bayh', 'Evan', '12/26/1955', 'M', 'Sen', 'IN', 'D', 1955, 1955], ['B ...
