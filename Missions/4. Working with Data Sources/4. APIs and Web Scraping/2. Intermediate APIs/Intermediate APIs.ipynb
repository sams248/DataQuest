# %% [markdown]
# # Intermediate APIs

# %% [markdown]
# We'll explore the GitHub API and use it to pull some interesting data on repositories and users.

# %%
import requests

# %% [markdown]
# ### API Authentication

# %%
# Make a GET request to the GitHub API with our headers (This API endpoint will give us details about Vik Paruchuri)

response = requests.get("https://api.github.com/users/VikParuchuri/orgs")

# %%
orgs = response.json()

# %%
orgs
# Out:
# [{'login': 'dataquestio',
#   'id': 11148054,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExMTQ4MDU0',
#   'url': 'https://api.github.com/orgs/dataquestio',
#   'repos_url': 'https://api.github.com/orgs/dataquestio/repos',
#   'events_url': 'https://api.github.com/orgs/dataquestio/events',
#   'hooks_url': 'https://api.github.com/orgs/dataquestio/hooks',
#   'issues_url': 'https://api.github.com/orgs/dataquestio/issues',
#   'members_url': 'https://api.github.com/orgs/dataquestio/members{/member}',
#   'public_members_url': 'https://api.github.com/orgs/dataquestio/public_members{/member}',
#   'avatar_url': 'https://avatars3.githubusercontent.com/u/11148054?v=4',
#   'description': 'Learn data science online'}]

# %% [markdown]
# ### Retrieve information about the Hello-World repository

# %%
response = requests.get("https://api.github.com/repos/octocat/Hello-World")
hello_world = response.json()

# %%
hello_world
# Out:
# {'id': 1296269,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxMjk2MjY5',
#  'name': 'Hello-World',
#  'full_name': 'octocat/Hello-World',
#  'private': False,
#  'owner': {'login': 'octocat',
#   'id': 583231,
#   'node_id': 'MDQ6VXNlcjU4MzIzMQ==',
#   'avatar_url': 'https://avatars3.githubusercontent.com/u/583231?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/octocat',
#   'html_url': 'https://github.com/octocat',
#   'followers_url': 'https://api.github.com/users/octocat/followers',
#   'following_url': 'https://api.github.com/users/octocat/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/octocat/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/octocat/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/octocat/subscriptions',
#   'organizations_url': 'https://api.github.com/users/octocat/orgs',
#   'repos_url': 'https://api.github.com/users/octocat/repos',
#   'events_url': 'https://api.github.com/users/octocat/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/octocat/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/octocat/Hello-World',
#  'description': 'My first repository on GitHub!',
#  'fork': False,
#  'url': 'https://api.github.com/repos/octocat/Hello-World',
#  'forks_url': 'https://api.github.com/repos/octocat/Hello-World/forks',
#  'keys_url': 'https://api.github.com/repos/octocat/Hello-World/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/octocat/Hello-World/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/octocat/Hello-World/teams',
#  'hooks_url': 'https://api.github.com/repos/octocat/Hello-World/hooks',
#  'issue_events_url': 'https://api.github.com/repos/octocat/Hello-World/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/octocat/Hello-World/events',
#  'assignees_url': 'https://api.github.com/repos/octocat/Hello-World/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/octocat/Hello-World/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/octocat/Hello-World/tags',
#  'blobs_url': 'https://api.github.com/repos/octocat/Hello-World/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/octocat/Hello-World/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/octocat/Hello-World/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/octocat/Hello-World/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/octocat/Hello-World/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/octocat/Hello-World/languages',
#  'stargazers_url': 'https://api.github.com/repos/octocat/Hello-World/stargazers',
#  'contributors_url': 'https://api.github.com/repos/octocat/Hello-World/contributors',
#  'subscribers_url': 'https://api.github.com/repos/octocat/Hello-World/subscribers',
#  'subscription_url': 'https://api.github.com/repos/octocat/Hello-World/subscription',
#  'commits_url': 'https://api.github.com/repos/octocat/Hello-World/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/octocat/Hello-World/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/octocat/Hello-World/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/octocat/Hello-World/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/octocat/Hello-World/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/octocat/Hello-World/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/octocat/Hello-World/merges',
#  'archive_url': 'https://api.github.com/repos/octocat/Hello-World/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/octocat/Hello-World/downloads',
#  'issues_url': 'https://api.github.com/repos/octocat/Hello-World/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/octocat/Hello-World/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/octocat/Hello-World/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/octocat/Hello-World/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/octocat/Hello-World/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/octocat/Hello-World/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/octocat/Hello-World/deployments',
#  'created_at': '2011-01-26T19:01:12Z',
#  'updated_at': '2018-11-02T17:27:08Z',
#  'pushed_at': '2018-10-31T12:23:19Z',
#  'git_url': 'git://github.com/octocat/Hello-World.git',
#  'ssh_url': 'git@github.com:octocat/Hello-World.git',
#  'clone_url': 'https://github.com/octocat/Hello-World.git',
#  'svn_url': 'https://github.com/octocat/Hello-World',
#  'homepage': '',
#  'size': 1,
#  'stargazers_count': 1467,
#  'watchers_count': 1467,
#  'language': None,
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 1313,
#  'mirror_url': None,
#  'archived': False,
#  'open_issues_count': 328,
#  'license': None,
#  'forks': 1313,
#  'open_issues': 328,
#  'watchers': 1467,
#  'default_branch': 'master',
#  'network_count': 1313,
#  'subscribers_count': 1562}

# %% [markdown]
# ### Pagination

# %%
# Get the second page of repositories that Vik Paruchuri starred

params = {
    "per_page": 50,
    "page": 2
}

response = requests.get("https://api.github.com/users/VikParuchuri/starred", params=params)

page2_repos = response.json()
page2_repos
# Out:
# [{'id': 99143276,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk5OTE0MzI3Ng==',
#   'name': 'ark',
#   'full_name': 'heptio/ark',
#   'private': False,
#   'owner': {'login': 'heptio',
#    'id': 22035492,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMDM1NDky',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/22035492?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/heptio',
#    'html_url': 'https://github.com/heptio',
#    'followers_url': 'https://api.github.com/users/heptio/followers',
#    'following_url': 'https://api.github.com/users/heptio/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/heptio/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/heptio/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/heptio/subscriptions',
#    'organizations_url': 'https://api.github.com/users/heptio/orgs',
#    'repos_url': 'https://api.github.com/users/heptio/repos',
#    'events_url': 'https://api.github.com/users/heptio/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/heptio/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/heptio/ark',
#   'description': 'Heptio Ark is a utility for managing disaster recovery, specifically for your Kubernetes cluster resources and persistent volumes. Brought to you by Heptio.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/heptio/ark',
#   'forks_url': 'https://api.github.com/repos/heptio/ark/forks',
#   'keys_url': 'https://api.github.com/repos/heptio/ark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/heptio/ark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/heptio/ark/teams',
#   'hooks_url': 'https://api.github.com/repos/heptio/ark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/heptio/ark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/heptio/ark/events',
#   'assignees_url': 'https://api.github.com/repos/heptio/ark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/heptio/ark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/heptio/ark/tags',
#   'blobs_url': 'https://api.github.com/repos/heptio/ark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/heptio/ark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/heptio/ark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/heptio/ark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/heptio/ark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/heptio/ark/languages',
#   'stargazers_url': 'https://api.github.com/repos/heptio/ark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/heptio/ark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/heptio/ark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/heptio/ark/subscription',
#   'commits_url': 'https://api.github.com/repos/heptio/ark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/heptio/ark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/heptio/ark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/heptio/ark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/heptio/ark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/heptio/ark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/heptio/ark/merges',
#   'archive_url': 'https://api.github.com/repos/heptio/ark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/heptio/ark/downloads',
#   'issues_url': 'https://api.github.com/repos/heptio/ark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/heptio/ark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/heptio/ark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/heptio/ark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/heptio/ark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/heptio/ark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/heptio/ark/deployments',
#   'created_at': '2017-08-02T17:22:11Z',
#   'updated_at': '2018-11-04T07:56:04Z',
#   'pushed_at': '2018-11-03T02:05:35Z',
#   'git_url': 'git://github.com/heptio/ark.git',
#   'ssh_url': 'git@github.com:heptio/ark.git',
#   'clone_url': 'https://github.com/heptio/ark.git',
#   'svn_url': 'https://github.com/heptio/ark',
#   'homepage': 'https://www.heptio.com',
#   'size': 11152,
#   'stargazers_count': 1651,
#   'watchers_count': 1651,
#   'language': 'Go',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': True,
#   'forks_count': 236,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 170,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 236,
#   'open_issues': 170,
#   'watchers': 1651,
#   'default_branch': 'release-0.9'},
#  {'id': 36172821,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjE3MjgyMQ==',
#   'name': 'embark',
#   'full_name': 'embark-framework/embark',
#   'private': False,
#   'owner': {'login': 'embark-framework',
#    'id': 12584440,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyNTg0NDQw',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/12584440?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/embark-framework',
#    'html_url': 'https://github.com/embark-framework',
#    'followers_url': 'https://api.github.com/users/embark-framework/followers',
#    'following_url': 'https://api.github.com/users/embark-framework/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/embark-framework/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/embark-framework/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/embark-framework/subscriptions',
#    'organizations_url': 'https://api.github.com/users/embark-framework/orgs',
#    'repos_url': 'https://api.github.com/users/embark-framework/repos',
#    'events_url': 'https://api.github.com/users/embark-framework/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/embark-framework/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/embark-framework/embark',
#   'description': 'Framework for serverless Decentralized Applications using Ethereum, IPFS and other platforms',
#   'fork': False,
#   'url': 'https://api.github.com/repos/embark-framework/embark',
#   'forks_url': 'https://api.github.com/repos/embark-framework/embark/forks',
#   'keys_url': 'https://api.github.com/repos/embark-framework/embark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/embark-framework/embark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/embark-framework/embark/teams',
#   'hooks_url': 'https://api.github.com/repos/embark-framework/embark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/embark-framework/embark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/embark-framework/embark/events',
#   'assignees_url': 'https://api.github.com/repos/embark-framework/embark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/embark-framework/embark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/embark-framework/embark/tags',
#   'blobs_url': 'https://api.github.com/repos/embark-framework/embark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/embark-framework/embark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/embark-framework/embark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/embark-framework/embark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/embark-framework/embark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/embark-framework/embark/languages',
#   'stargazers_url': 'https://api.github.com/repos/embark-framework/embark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/embark-framework/embark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/embark-framework/embark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/embark-framework/embark/subscription',
#   'commits_url': 'https://api.github.com/repos/embark-framework/embark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/embark-framework/embark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/embark-framework/embark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/embark-framework/embark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/embark-framework/embark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/embark-framework/embark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/embark-framework/embark/merges',
#   'archive_url': 'https://api.github.com/repos/embark-framework/embark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/embark-framework/embark/downloads',
#   'issues_url': 'https://api.github.com/repos/embark-framework/embark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/embark-framework/embark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/embark-framework/embark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/embark-framework/embark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/embark-framework/embark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/embark-framework/embark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/embark-framework/embark/deployments',
#   'created_at': '2015-05-24T13:10:10Z',
#   'updated_at': '2018-11-04T16:55:40Z',
#   'pushed_at': '2018-11-01T13:11:59Z',
#   'git_url': 'git://github.com/embark-framework/embark.git',
#   'ssh_url': 'git@github.com:embark-framework/embark.git',
#   'clone_url': 'https://github.com/embark-framework/embark.git',
#   'svn_url': 'https://github.com/embark-framework/embark',
#   'homepage': 'https://embark.status.im/',
#   'size': 19828,
#   'stargazers_count': 2489,
#   'watchers_count': 2489,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 362,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 46,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 362,
#   'open_issues': 46,
#   'watchers': 2489,
#   'default_branch': 'develop'},
#  {'id': 85393329,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk4NTM5MzMyOQ==',
#   'name': 'mesh',
#   'full_name': 'chrispsn/mesh',
#   'private': False,
#   'owner': {'login': 'chrispsn',
#    'id': 777010,
#    'node_id': 'MDQ6VXNlcjc3NzAxMA==',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/777010?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chrispsn',
#    'html_url': 'https://github.com/chrispsn',
#    'followers_url': 'https://api.github.com/users/chrispsn/followers',
#    'following_url': 'https://api.github.com/users/chrispsn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chrispsn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/chrispsn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chrispsn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/chrispsn/orgs',
#    'repos_url': 'https://api.github.com/users/chrispsn/repos',
#    'events_url': 'https://api.github.com/users/chrispsn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/chrispsn/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/chrispsn/mesh',
#   'description': 'Visualise data and edit JavaScript code using a spreadsheet interface.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/chrispsn/mesh',
#   'forks_url': 'https://api.github.com/repos/chrispsn/mesh/forks',
#   'keys_url': 'https://api.github.com/repos/chrispsn/mesh/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/chrispsn/mesh/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/chrispsn/mesh/teams',
#   'hooks_url': 'https://api.github.com/repos/chrispsn/mesh/hooks',
#   'issue_events_url': 'https://api.github.com/repos/chrispsn/mesh/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/chrispsn/mesh/events',
#   'assignees_url': 'https://api.github.com/repos/chrispsn/mesh/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/chrispsn/mesh/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/chrispsn/mesh/tags',
#   'blobs_url': 'https://api.github.com/repos/chrispsn/mesh/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/chrispsn/mesh/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/chrispsn/mesh/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/chrispsn/mesh/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/chrispsn/mesh/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/chrispsn/mesh/languages',
#   'stargazers_url': 'https://api.github.com/repos/chrispsn/mesh/stargazers',
#   'contributors_url': 'https://api.github.com/repos/chrispsn/mesh/contributors',
#   'subscribers_url': 'https://api.github.com/repos/chrispsn/mesh/subscribers',
#   'subscription_url': 'https://api.github.com/repos/chrispsn/mesh/subscription',
#   'commits_url': 'https://api.github.com/repos/chrispsn/mesh/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/chrispsn/mesh/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/chrispsn/mesh/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/chrispsn/mesh/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/chrispsn/mesh/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/chrispsn/mesh/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/chrispsn/mesh/merges',
#   'archive_url': 'https://api.github.com/repos/chrispsn/mesh/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/chrispsn/mesh/downloads',
#   'issues_url': 'https://api.github.com/repos/chrispsn/mesh/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/chrispsn/mesh/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/chrispsn/mesh/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/chrispsn/mesh/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/chrispsn/mesh/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/chrispsn/mesh/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/chrispsn/mesh/deployments',
#   'created_at': '2017-03-18T10:32:11Z',
#   'updated_at': '2018-11-04T07:36:19Z',
#   'pushed_at': '2018-11-04T07:36:17Z',
#   'git_url': 'git://github.com/chrispsn/mesh.git',
#   'ssh_url': 'git@github.com:chrispsn/mesh.git',
#   'clone_url': 'https://github.com/chrispsn/mesh.git',
#   'svn_url': 'https://github.com/chrispsn/mesh',
#   'homepage': 'http://mesh-spreadsheet.com',
#   'size': 1645,
#   'stargazers_count': 817,
#   'watchers_count': 817,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 39,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 34,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'forks': 39,
#   'open_issues': 34,
#   'watchers': 817,
#   'default_branch': 'master'},
#  {'id': 13840241,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMzg0MDI0MQ==',
#   'name': 'devdocs',
#   'full_name': 'freeCodeCamp/devdocs',
#   'private': False,
#   'owner': {'login': 'freeCodeCamp',
#    'id': 9892522,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk4OTI1MjI=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/9892522?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freeCodeCamp',
#    'html_url': 'https://github.com/freeCodeCamp',
#    'followers_url': 'https://api.github.com/users/freeCodeCamp/followers',
#    'following_url': 'https://api.github.com/users/freeCodeCamp/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/freeCodeCamp/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/freeCodeCamp/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/freeCodeCamp/subscriptions',
#    'organizations_url': 'https://api.github.com/users/freeCodeCamp/orgs',
#    'repos_url': 'https://api.github.com/users/freeCodeCamp/repos',
#    'events_url': 'https://api.github.com/users/freeCodeCamp/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/freeCodeCamp/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/freeCodeCamp/devdocs',
#   'description': 'API Documentation Browser',
#   'fork': False,
#   'url': 'https://api.github.com/repos/freeCodeCamp/devdocs',
#   'forks_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/forks',
#   'keys_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/teams',
#   'hooks_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/events',
#   'assignees_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/tags',
#   'blobs_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/languages',
#   'stargazers_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/subscription',
#   'commits_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/merges',
#   'archive_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/downloads',
#   'issues_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/freeCodeCamp/devdocs/deployments',
#   'created_at': '2013-10-24T18:16:07Z',
#   'updated_at': '2018-11-04T16:07:57Z',
#   'pushed_at': '2018-11-04T13:56:02Z',
#   'git_url': 'git://github.com/freeCodeCamp/devdocs.git',
#   'ssh_url': 'git@github.com:freeCodeCamp/devdocs.git',
#   'clone_url': 'https://github.com/freeCodeCamp/devdocs.git',
#   'svn_url': 'https://github.com/freeCodeCamp/devdocs',
#   'homepage': 'https://devdocs.io',
#   'size': 16682,
#   'stargazers_count': 19130,
#   'watchers_count': 19130,
#   'language': 'Ruby',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1243,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 91,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'forks': 1243,
#   'open_issues': 91,
#   'watchers': 19130,
#   'default_branch': 'master'},
#  {'id': 59693422,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1OTY5MzQyMg==',
#   'name': 'gr-amps',
#   'full_name': 'unsynchronized/gr-amps',
#   'private': False,
#   'owner': {'login': 'unsynchronized',
#    'id': 640023,
#    'node_id': 'MDQ6VXNlcjY0MDAyMw==',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/640023?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/unsynchronized',
#    'html_url': 'https://github.com/unsynchronized',
#    'followers_url': 'https://api.github.com/users/unsynchronized/followers',
#    'following_url': 'https://api.github.com/users/unsynchronized/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/unsynchronized/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/unsynchronized/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/unsynchronized/subscriptions',
#    'organizations_url': 'https://api.github.com/users/unsynchronized/orgs',
#    'repos_url': 'https://api.github.com/users/unsynchronized/repos',
#    'events_url': 'https://api.github.com/users/unsynchronized/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/unsynchronized/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/unsynchronized/gr-amps',
#   'description': 'modern gnuradio blocks for AMPS mobile devices',
#   'fork': False,
#   'url': 'https://api.github.com/repos/unsynchronized/gr-amps',
#   'forks_url': 'https://api.github.com/repos/unsynchronized/gr-amps/forks',
#   'keys_url': 'https://api.github.com/repos/unsynchronized/gr-amps/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/unsynchronized/gr-amps/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/unsynchronized/gr-amps/teams',
#   'hooks_url': 'https://api.github.com/repos/unsynchronized/gr-amps/hooks',
#   'issue_events_url': 'https://api.github.com/repos/unsynchronized/gr-amps/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/unsynchronized/gr-amps/events',
#   'assignees_url': 'https://api.github.com/repos/unsynchronized/gr-amps/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/unsynchronized/gr-amps/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/unsynchronized/gr-amps/tags',
#   'blobs_url': 'https://api.github.com/repos/unsynchronized/gr-amps/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/unsynchronized/gr-amps/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/unsynchronized/gr-amps/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/unsynchronized/gr-amps/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/unsynchronized/gr-amps/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/unsynchronized/gr-amps/languages',
#   'stargazers_url': 'https://api.github.com/repos/unsynchronized/gr-amps/stargazers',
#   'contributors_url': 'https://api.github.com/repos/unsynchronized/gr-amps/contributors',
#   'subscribers_url': 'https://api.github.com/repos/unsynchronized/gr-amps/subscribers',
#   'subscription_url': 'https://api.github.com/repos/unsynchronized/gr-amps/subscription',
#   'commits_url': 'https://api.github.com/repos/unsynchronized/gr-amps/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/unsynchronized/gr-amps/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/unsynchronized/gr-amps/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/unsynchronized/gr-amps/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/unsynchronized/gr-amps/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/unsynchronized/gr-amps/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/unsynchronized/gr-amps/merges',
#   'archive_url': 'https://api.github.com/repos/unsynchronized/gr-amps/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/unsynchronized/gr-amps/downloads',
#   'issues_url': 'https://api.github.com/repos/unsynchronized/gr-amps/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/unsynchronized/gr-amps/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/unsynchronized/gr-amps/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/unsynchronized/gr-amps/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/unsynchronized/gr-amps/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/unsynchronized/gr-amps/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/unsynchronized/gr-amps/deployments',
#   'created_at': '2016-05-25T19:57:13Z',
#   'updated_at': '2018-10-29T05:13:18Z',
#   'pushed_at': '2017-11-03T22:38:29Z',
#   'git_url': 'git://github.com/unsynchronized/gr-amps.git',
#   'ssh_url': 'git@github.com:unsynchronized/gr-amps.git',
#   'clone_url': 'https://github.com/unsynchronized/gr-amps.git',
#   'svn_url': 'https://github.com/unsynchronized/gr-amps',
#   'homepage': '',
#   'size': 311,
#   'stargazers_count': 133,
#   'watchers_count': 133,
#   'language': 'C++',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 29,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 29,
#   'open_issues': 0,
#   'watchers': 133,
#   'default_branch': 'master'},
#  {'id': 6694031,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2Njk0MDMx',
#   'name': 'interactive-lp',
#   'full_name': 'chrisamaphone/interactive-lp',
#   'private': False,
#   'owner': {'login': 'chrisamaphone',
#    'id': 498750,
#    'node_id': 'MDQ6VXNlcjQ5ODc1MA==',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/498750?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chrisamaphone',
#    'html_url': 'https://github.com/chrisamaphone',
#    'followers_url': 'https://api.github.com/users/chrisamaphone/followers',
#    'following_url': 'https://api.github.com/users/chrisamaphone/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chrisamaphone/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/chrisamaphone/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chrisamaphone/subscriptions',
#    'organizations_url': 'https://api.github.com/users/chrisamaphone/orgs',
#    'repos_url': 'https://api.github.com/users/chrisamaphone/repos',
#    'events_url': 'https://api.github.com/users/chrisamaphone/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/chrisamaphone/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/chrisamaphone/interactive-lp',
#   'description': 'Project materials related to logic programming for interactive/reactive systems.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/chrisamaphone/interactive-lp',
#   'forks_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/forks',
#   'keys_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/teams',
#   'hooks_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/events',
#   'assignees_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/tags',
#   'blobs_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/languages',
#   'stargazers_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/subscription',
#   'commits_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/merges',
#   'archive_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/downloads',
#   'issues_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/chrisamaphone/interactive-lp/deployments',
#   'created_at': '2012-11-14T20:02:53Z',
#   'updated_at': '2018-11-03T03:33:07Z',
#   'pushed_at': '2018-10-31T19:31:20Z',
#   'git_url': 'git://github.com/chrisamaphone/interactive-lp.git',
#   'ssh_url': 'git@github.com:chrisamaphone/interactive-lp.git',
#   'clone_url': 'https://github.com/chrisamaphone/interactive-lp.git',
#   'svn_url': 'https://github.com/chrisamaphone/interactive-lp',
#   'homepage': None,
#   'size': 3164,
#   'stargazers_count': 162,
#   'watchers_count': 162,
#   'language': 'Standard ML',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 13,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 2,
#   'license': None,
#   'forks': 13,
#   'open_issues': 2,
#   'watchers': 162,
#   'default_branch': 'master'},
#  {'id': 83050680,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk4MzA1MDY4MA==',
#   'name': 'theia',
#   'full_name': 'theia-ide/theia',
#   'private': False,
#   'owner': {'login': 'theia-ide',
#    'id': 28530323,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4NTMwMzIz',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/28530323?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/theia-ide',
#    'html_url': 'https://github.com/theia-ide',
#    'followers_url': 'https://api.github.com/users/theia-ide/followers',
#    'following_url': 'https://api.github.com/users/theia-ide/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/theia-ide/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/theia-ide/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/theia-ide/subscriptions',
#    'organizations_url': 'https://api.github.com/users/theia-ide/orgs',
#    'repos_url': 'https://api.github.com/users/theia-ide/repos',
#    'events_url': 'https://api.github.com/users/theia-ide/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/theia-ide/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/theia-ide/theia',
#   'description': 'Theia is a cloud & desktop IDE framework implemented in TypeScript.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/theia-ide/theia',
#   'forks_url': 'https://api.github.com/repos/theia-ide/theia/forks',
#   'keys_url': 'https://api.github.com/repos/theia-ide/theia/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/theia-ide/theia/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/theia-ide/theia/teams',
#   'hooks_url': 'https://api.github.com/repos/theia-ide/theia/hooks',
#   'issue_events_url': 'https://api.github.com/repos/theia-ide/theia/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/theia-ide/theia/events',
#   'assignees_url': 'https://api.github.com/repos/theia-ide/theia/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/theia-ide/theia/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/theia-ide/theia/tags',
#   'blobs_url': 'https://api.github.com/repos/theia-ide/theia/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/theia-ide/theia/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/theia-ide/theia/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/theia-ide/theia/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/theia-ide/theia/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/theia-ide/theia/languages',
#   'stargazers_url': 'https://api.github.com/repos/theia-ide/theia/stargazers',
#   'contributors_url': 'https://api.github.com/repos/theia-ide/theia/contributors',
#   'subscribers_url': 'https://api.github.com/repos/theia-ide/theia/subscribers',
#   'subscription_url': 'https://api.github.com/repos/theia-ide/theia/subscription',
#   'commits_url': 'https://api.github.com/repos/theia-ide/theia/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/theia-ide/theia/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/theia-ide/theia/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/theia-ide/theia/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/theia-ide/theia/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/theia-ide/theia/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/theia-ide/theia/merges',
#   'archive_url': 'https://api.github.com/repos/theia-ide/theia/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/theia-ide/theia/downloads',
#   'issues_url': 'https://api.github.com/repos/theia-ide/theia/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/theia-ide/theia/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/theia-ide/theia/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/theia-ide/theia/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/theia-ide/theia/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/theia-ide/theia/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/theia-ide/theia/deployments',
#   'created_at': '2017-02-24T14:42:05Z',
#   'updated_at': '2018-11-04T19:25:30Z',
#   'pushed_at': '2018-11-04T10:49:06Z',
#   'git_url': 'git://github.com/theia-ide/theia.git',
#   'ssh_url': 'git@github.com:theia-ide/theia.git',
#   'clone_url': 'https://github.com/theia-ide/theia.git',
#   'svn_url': 'https://github.com/theia-ide/theia',
#   'homepage': 'http://theia-ide.org',
#   'size': 111636,
#   'stargazers_count': 1799,
#   'watchers_count': 1799,
#   'language': 'TypeScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 263,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 708,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'forks': 263,
#   'open_issues': 708,
#   'watchers': 1799,
#   'default_branch': 'master'},
#  {'id': 43519457,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MzUxOTQ1Nw==',
#   'name': 'iplotter',
#   'full_name': 'niloch/iplotter',
#   'private': False,
#   'owner': {'login': 'niloch',
#    'id': 6801168,
#    'node_id': 'MDQ6VXNlcjY4MDExNjg=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/6801168?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/niloch',
#    'html_url': 'https://github.com/niloch',
#    'followers_url': 'https://api.github.com/users/niloch/followers',
#    'following_url': 'https://api.github.com/users/niloch/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/niloch/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/niloch/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/niloch/subscriptions',
#    'organizations_url': 'https://api.github.com/users/niloch/orgs',
#    'repos_url': 'https://api.github.com/users/niloch/repos',
#    'events_url': 'https://api.github.com/users/niloch/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/niloch/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/niloch/iplotter',
#   'description': 'JavaScript charting in ipython/jupyter notebooks - ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/niloch/iplotter',
#   'forks_url': 'https://api.github.com/repos/niloch/iplotter/forks',
#   'keys_url': 'https://api.github.com/repos/niloch/iplotter/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/niloch/iplotter/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/niloch/iplotter/teams',
#   'hooks_url': 'https://api.github.com/repos/niloch/iplotter/hooks',
#   'issue_events_url': 'https://api.github.com/repos/niloch/iplotter/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/niloch/iplotter/events',
#   'assignees_url': 'https://api.github.com/repos/niloch/iplotter/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/niloch/iplotter/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/niloch/iplotter/tags',
#   'blobs_url': 'https://api.github.com/repos/niloch/iplotter/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/niloch/iplotter/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/niloch/iplotter/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/niloch/iplotter/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/niloch/iplotter/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/niloch/iplotter/languages',
#   'stargazers_url': 'https://api.github.com/repos/niloch/iplotter/stargazers',
#   'contributors_url': 'https://api.github.com/repos/niloch/iplotter/contributors',
#   'subscribers_url': 'https://api.github.com/repos/niloch/iplotter/subscribers',
#   'subscription_url': 'https://api.github.com/repos/niloch/iplotter/subscription',
#   'commits_url': 'https://api.github.com/repos/niloch/iplotter/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/niloch/iplotter/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/niloch/iplotter/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/niloch/iplotter/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/niloch/iplotter/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/niloch/iplotter/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/niloch/iplotter/merges',
#   'archive_url': 'https://api.github.com/repos/niloch/iplotter/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/niloch/iplotter/downloads',
#   'issues_url': 'https://api.github.com/repos/niloch/iplotter/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/niloch/iplotter/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/niloch/iplotter/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/niloch/iplotter/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/niloch/iplotter/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/niloch/iplotter/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/niloch/iplotter/deployments',
#   'created_at': '2015-10-01T20:33:02Z',
#   'updated_at': '2018-09-26T15:04:53Z',
#   'pushed_at': '2017-09-30T02:52:59Z',
#   'git_url': 'git://github.com/niloch/iplotter.git',
#   'ssh_url': 'git@github.com:niloch/iplotter.git',
#   'clone_url': 'https://github.com/niloch/iplotter.git',
#   'svn_url': 'https://github.com/niloch/iplotter',
#   'homepage': 'http://niloch.github.io/iplotter/',
#   'size': 858,
#   'stargazers_count': 71,
#   'watchers_count': 71,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'forks_count': 6,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 1,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 6,
#   'open_issues': 1,
#   'watchers': 71,
#   'default_branch': 'master'},
#  {'id': 37883782,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNzg4Mzc4Mg==',
#   'name': 'pyxley',
#   'full_name': 'stitchfix/pyxley',
#   'private': False,
#   'owner': {'login': 'stitchfix',
#    'id': 1749260,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3NDkyNjA=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/1749260?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stitchfix',
#    'html_url': 'https://github.com/stitchfix',
#    'followers_url': 'https://api.github.com/users/stitchfix/followers',
#    'following_url': 'https://api.github.com/users/stitchfix/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stitchfix/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stitchfix/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stitchfix/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stitchfix/orgs',
#    'repos_url': 'https://api.github.com/users/stitchfix/repos',
#    'events_url': 'https://api.github.com/users/stitchfix/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stitchfix/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/stitchfix/pyxley',
#   'description': 'Python helpers for building dashboards using Flask and React',
#   'fork': False,
#   'url': 'https://api.github.com/repos/stitchfix/pyxley',
#   'forks_url': 'https://api.github.com/repos/stitchfix/pyxley/forks',
#   'keys_url': 'https://api.github.com/repos/stitchfix/pyxley/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/stitchfix/pyxley/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/stitchfix/pyxley/teams',
#   'hooks_url': 'https://api.github.com/repos/stitchfix/pyxley/hooks',
#   'issue_events_url': 'https://api.github.com/repos/stitchfix/pyxley/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/stitchfix/pyxley/events',
#   'assignees_url': 'https://api.github.com/repos/stitchfix/pyxley/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/stitchfix/pyxley/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/stitchfix/pyxley/tags',
#   'blobs_url': 'https://api.github.com/repos/stitchfix/pyxley/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/stitchfix/pyxley/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/stitchfix/pyxley/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/stitchfix/pyxley/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/stitchfix/pyxley/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/stitchfix/pyxley/languages',
#   'stargazers_url': 'https://api.github.com/repos/stitchfix/pyxley/stargazers',
#   'contributors_url': 'https://api.github.com/repos/stitchfix/pyxley/contributors',
#   'subscribers_url': 'https://api.github.com/repos/stitchfix/pyxley/subscribers',
#   'subscription_url': 'https://api.github.com/repos/stitchfix/pyxley/subscription',
#   'commits_url': 'https://api.github.com/repos/stitchfix/pyxley/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/stitchfix/pyxley/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/stitchfix/pyxley/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/stitchfix/pyxley/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/stitchfix/pyxley/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/stitchfix/pyxley/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/stitchfix/pyxley/merges',
#   'archive_url': 'https://api.github.com/repos/stitchfix/pyxley/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/stitchfix/pyxley/downloads',
#   'issues_url': 'https://api.github.com/repos/stitchfix/pyxley/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/stitchfix/pyxley/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/stitchfix/pyxley/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/stitchfix/pyxley/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/stitchfix/pyxley/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/stitchfix/pyxley/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/stitchfix/pyxley/deployments',
#   'created_at': '2015-06-22T22:23:26Z',
#   'updated_at': '2018-11-01T14:37:19Z',
#   'pushed_at': '2018-03-06T21:13:30Z',
#   'git_url': 'git://github.com/stitchfix/pyxley.git',
#   'ssh_url': 'git@github.com:stitchfix/pyxley.git',
#   'clone_url': 'https://github.com/stitchfix/pyxley.git',
#   'svn_url': 'https://github.com/stitchfix/pyxley',
#   'homepage': None,
#   'size': 5687,
#   'stargazers_count': 2129,
#   'watchers_count': 2129,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 238,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 27,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
# ...
#    'following_url': 'https://api.github.com/users/dunovank/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dunovank/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dunovank/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dunovank/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dunovank/orgs',
#    'repos_url': 'https://api.github.com/users/dunovank/repos',
#    'events_url': 'https://api.github.com/users/dunovank/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dunovank/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/dunovank/jupyter-themes',
#   'description': 'Custom Jupyter Notebook Themes',
#   'fork': False,
#   'url': 'https://api.github.com/repos/dunovank/jupyter-themes',
#   'forks_url': 'https://api.github.com/repos/dunovank/jupyter-themes/forks',
#   'keys_url': 'https://api.github.com/repos/dunovank/jupyter-themes/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/dunovank/jupyter-themes/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/dunovank/jupyter-themes/teams',
#   'hooks_url': 'https://api.github.com/repos/dunovank/jupyter-themes/hooks',
#   'issue_events_url': 'https://api.github.com/repos/dunovank/jupyter-themes/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/dunovank/jupyter-themes/events',
#   'assignees_url': 'https://api.github.com/repos/dunovank/jupyter-themes/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/dunovank/jupyter-themes/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/dunovank/jupyter-themes/tags',
#   'blobs_url': 'https://api.github.com/repos/dunovank/jupyter-themes/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/dunovank/jupyter-themes/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/dunovank/jupyter-themes/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/dunovank/jupyter-themes/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/dunovank/jupyter-themes/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/dunovank/jupyter-themes/languages',
#   'stargazers_url': 'https://api.github.com/repos/dunovank/jupyter-themes/stargazers',
#   'contributors_url': 'https://api.github.com/repos/dunovank/jupyter-themes/contributors',
#   'subscribers_url': 'https://api.github.com/repos/dunovank/jupyter-themes/subscribers',
#   'subscription_url': 'https://api.github.com/repos/dunovank/jupyter-themes/subscription',
#   'commits_url': 'https://api.github.com/repos/dunovank/jupyter-themes/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/dunovank/jupyter-themes/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/dunovank/jupyter-themes/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/dunovank/jupyter-themes/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/dunovank/jupyter-themes/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/dunovank/jupyter-themes/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/dunovank/jupyter-themes/merges',
#   'archive_url': 'https://api.github.com/repos/dunovank/jupyter-themes/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/dunovank/jupyter-themes/downloads',
#   'issues_url': 'https://api.github.com/repos/dunovank/jupyter-themes/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/dunovank/jupyter-themes/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/dunovank/jupyter-themes/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/dunovank/jupyter-themes/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/dunovank/jupyter-themes/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/dunovank/jupyter-themes/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/dunovank/jupyter-themes/deployments',
#   'created_at': '2014-12-10T23:22:23Z',
#   'updated_at': '2018-11-04T05:32:38Z',
#   'pushed_at': '2018-10-31T13:00:59Z',
#   'git_url': 'git://github.com/dunovank/jupyter-themes.git',
#   'ssh_url': 'git@github.com:dunovank/jupyter-themes.git',
#   'clone_url': 'https://github.com/dunovank/jupyter-themes.git',
#   'svn_url': 'https://github.com/dunovank/jupyter-themes',
#   'homepage': '',
#   'size': 46084,
#   'stargazers_count': 4405,
#   'watchers_count': 4405,
#   'language': 'CSS',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 501,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 94,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 501,
#   'open_issues': 94,
#   'watchers': 4405,
#   'default_branch': 'master'},
#  {'id': 3769702,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNzY5NzAy',
#   'name': 'pootle',
#   'full_name': 'translate/pootle',
#   'private': False,
#   'owner': {'login': 'translate',
#    'id': 1538178,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1MzgxNzg=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1538178?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/translate',
#    'html_url': 'https://github.com/translate',
#    'followers_url': 'https://api.github.com/users/translate/followers',
#    'following_url': 'https://api.github.com/users/translate/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/translate/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/translate/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/translate/subscriptions',
#    'organizations_url': 'https://api.github.com/users/translate/orgs',
#    'repos_url': 'https://api.github.com/users/translate/repos',
#    'events_url': 'https://api.github.com/users/translate/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/translate/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/translate/pootle',
#   'description': 'Online translation tool',
#   'fork': False,
#   'url': 'https://api.github.com/repos/translate/pootle',
#   'forks_url': 'https://api.github.com/repos/translate/pootle/forks',
#   'keys_url': 'https://api.github.com/repos/translate/pootle/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/translate/pootle/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/translate/pootle/teams',
#   'hooks_url': 'https://api.github.com/repos/translate/pootle/hooks',
#   'issue_events_url': 'https://api.github.com/repos/translate/pootle/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/translate/pootle/events',
#   'assignees_url': 'https://api.github.com/repos/translate/pootle/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/translate/pootle/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/translate/pootle/tags',
#   'blobs_url': 'https://api.github.com/repos/translate/pootle/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/translate/pootle/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/translate/pootle/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/translate/pootle/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/translate/pootle/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/translate/pootle/languages',
#   'stargazers_url': 'https://api.github.com/repos/translate/pootle/stargazers',
#   'contributors_url': 'https://api.github.com/repos/translate/pootle/contributors',
#   'subscribers_url': 'https://api.github.com/repos/translate/pootle/subscribers',
#   'subscription_url': 'https://api.github.com/repos/translate/pootle/subscription',
#   'commits_url': 'https://api.github.com/repos/translate/pootle/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/translate/pootle/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/translate/pootle/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/translate/pootle/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/translate/pootle/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/translate/pootle/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/translate/pootle/merges',
#   'archive_url': 'https://api.github.com/repos/translate/pootle/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/translate/pootle/downloads',
#   'issues_url': 'https://api.github.com/repos/translate/pootle/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/translate/pootle/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/translate/pootle/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/translate/pootle/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/translate/pootle/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/translate/pootle/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/translate/pootle/deployments',
#   'created_at': '2012-03-19T23:06:03Z',
#   'updated_at': '2018-11-02T13:04:47Z',
#   'pushed_at': '2018-11-04T15:35:44Z',
#   'git_url': 'git://github.com/translate/pootle.git',
#   'ssh_url': 'git@github.com:translate/pootle.git',
#   'clone_url': 'https://github.com/translate/pootle.git',
#   'svn_url': 'https://github.com/translate/pootle',
#   'homepage': 'http://pootle.translatehouse.org',
#   'size': 126118,
#   'stargazers_count': 1069,
#   'watchers_count': 1069,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': True,
#   'forks_count': 259,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 511,
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='},
#   'forks': 259,
#   'open_issues': 511,
#   'watchers': 1069,
#   'default_branch': 'master'},
#  {'id': 72792222,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3Mjc5MjIyMg==',
#   'name': 'parrot',
#   'full_name': 'parrot-translate/parrot',
#   'private': False,
#   'owner': {'login': 'parrot-translate',
#    'id': 35376269,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM1Mzc2MjY5',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/35376269?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/parrot-translate',
#    'html_url': 'https://github.com/parrot-translate',
#    'followers_url': 'https://api.github.com/users/parrot-translate/followers',
#    'following_url': 'https://api.github.com/users/parrot-translate/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/parrot-translate/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/parrot-translate/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/parrot-translate/subscriptions',
#    'organizations_url': 'https://api.github.com/users/parrot-translate/orgs',
#    'repos_url': 'https://api.github.com/users/parrot-translate/repos',
#    'events_url': 'https://api.github.com/users/parrot-translate/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/parrot-translate/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/parrot-translate/parrot',
#   'description': 'Self-hosted Localization Management Platform built with Go and Angular 2',
#   'fork': False,
#   'url': 'https://api.github.com/repos/parrot-translate/parrot',
#   'forks_url': 'https://api.github.com/repos/parrot-translate/parrot/forks',
#   'keys_url': 'https://api.github.com/repos/parrot-translate/parrot/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/parrot-translate/parrot/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/parrot-translate/parrot/teams',
#   'hooks_url': 'https://api.github.com/repos/parrot-translate/parrot/hooks',
#   'issue_events_url': 'https://api.github.com/repos/parrot-translate/parrot/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/parrot-translate/parrot/events',
#   'assignees_url': 'https://api.github.com/repos/parrot-translate/parrot/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/parrot-translate/parrot/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/parrot-translate/parrot/tags',
#   'blobs_url': 'https://api.github.com/repos/parrot-translate/parrot/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/parrot-translate/parrot/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/parrot-translate/parrot/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/parrot-translate/parrot/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/parrot-translate/parrot/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/parrot-translate/parrot/languages',
#   'stargazers_url': 'https://api.github.com/repos/parrot-translate/parrot/stargazers',
#   'contributors_url': 'https://api.github.com/repos/parrot-translate/parrot/contributors',
#   'subscribers_url': 'https://api.github.com/repos/parrot-translate/parrot/subscribers',
#   'subscription_url': 'https://api.github.com/repos/parrot-translate/parrot/subscription',
#   'commits_url': 'https://api.github.com/repos/parrot-translate/parrot/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/parrot-translate/parrot/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/parrot-translate/parrot/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/parrot-translate/parrot/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/parrot-translate/parrot/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/parrot-translate/parrot/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/parrot-translate/parrot/merges',
#   'archive_url': 'https://api.github.com/repos/parrot-translate/parrot/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/parrot-translate/parrot/downloads',
#   'issues_url': 'https://api.github.com/repos/parrot-translate/parrot/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/parrot-translate/parrot/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/parrot-translate/parrot/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/parrot-translate/parrot/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/parrot-translate/parrot/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/parrot-translate/parrot/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/parrot-translate/parrot/deployments',
#   'created_at': '2016-11-03T22:23:11Z',
#   'updated_at': '2018-10-29T09:05:18Z',
#   'pushed_at': '2018-05-26T00:48:33Z',
#   'git_url': 'git://github.com/parrot-translate/parrot.git',
#   'ssh_url': 'git@github.com:parrot-translate/parrot.git',
#   'clone_url': 'https://github.com/parrot-translate/parrot.git',
#   'svn_url': 'https://github.com/parrot-translate/parrot',
#   'homepage': 'http://parrot-translate.github.io/parrot.github.io/',
#   'size': 5692,
#   'stargazers_count': 962,
#   'watchers_count': 962,
#   'language': 'TypeScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 72,
#   'mirror_url': None,
#   'archived': False,
#   'open_issues_count': 27,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'forks': 72,
#   'open_issues': 27,
#   'watchers': 962,
#   'default_branch': 'master'}]

# %% [markdown]
# ### User-level Endpoints

# %%
headers = {"Authorization": "token 1f36137fbbe1602f779300dad26e4c1b7fbab631"}
response = requests.get("https://api.github.com/user", headers=headers)
user = response.json()
user
# Out:
# {'message': 'Bad credentials',
#  'documentation_url': 'https://developer.github.com/v3'}

# %% [markdown]
# **Note : This token has been revoked. Hence, the 401 status codes in the following! **

# %% [markdown]
# ### POST requests

# %%
payload = {"name": "learning-about-apis"}

response = requests.post("https://api.github.com/user/repos", json=payload, headers=headers)
status = response.status_code
status
# Out:
# 401

# %% [markdown]
# ### PUT/PATCH requests

# %%
payload = {"description": "The best repository ever!", "name": "test"}

response = requests.patch("https://api.github.com/repos/VikParuchuri/test", json=payload)
print(response.status_code)
# Out:
# 404

# %%
payload = {"description": "Learning about requests!", "name": "learning-about-apis"}
response = requests.patch("https://api.github.com/repos/VikParuchuri/learning-about-apis", json=payload, headers=headers)
status = response.status_code
status
# Out:
# 401

# %% [markdown]
# ### DELETE requests

# %%
response = requests.delete("https://api.github.com/repos/VikParuchuri/test", headers=headers)
print(response.status_code)
# Out:
# 401
